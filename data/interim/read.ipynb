# %%
import pandas as pd

df = pd.read_parquet("D:\ProjectNCKH\deep_finance\data\interim\concatenated_news_filtered.parquet")
print(df.head())
# Out:
#               author                                            content  \
# 0     Ananya Gairola  Amazon.com Inc (NASDAQ: AMZN ) CEO Andy Jassy ...
# 1  Shivani Kumaresan  Brookfield Asset Management Ltd (NYSE: BAM ), ...
# 2     Anusuya Lahiri  Alibaba Group Holding Limited (NYSE: BABA ) pl...
# 3     Anusuya Lahiri  Flex Ltd (NASDAQ: FLEX ) traded lower by about...
# 4   The Arora Report  To gain an edge, this is what you need to know...
#
#              datetime    source  \
# 0 2024-05-01 01:45:09  benzinga
# 1 2024-05-01 15:49:15  benzinga
# 2 2024-05-01 15:21:22  benzinga
# 3 2024-05-01 15:04:09  benzinga
# 4 2024-05-01 14:57:45  benzinga
#
#                                              summary  \
# 0  During Amazon&#39;s first-quarter 2024 earning...
# 1  Microsoft solidifies its commitment to sustain...
# 2  Alibaba to build data center in Vietnam to com...
# 3  Flex Ltd (NASDAQ: FLEX) reported strong 4Q 202...
# 4  To gain an edge, this is what you need to know...
#
# ...

# %%
df
